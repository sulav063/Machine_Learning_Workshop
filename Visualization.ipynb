# %% [markdown]
# <a href="https://colab.research.google.com/github/sulav063/Machine_Learning_Workshop/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Why Choose Matplotlib and Seaborn?

# %% [markdown]
# Both libraries are among the most popular choices for data visualization in Python. Here’s why:
#
# Matplotlib: Known for its flexibility, Matplotlib allows detailed customization of visual elements, making it perfect for tailored plots.
#
# Seaborn: Built on top of Matplotlib, Seaborn simplifies visualization tasks by offering high-level functions to create aesthetically pleasing statistical graphics.

# %% [markdown]
# ## Basic of Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Line Plot
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x,y)

# %%
categories = ['A', 'B', 'C']
values = [10, 20, 15]
colors = ['skyblue', 'lightcoral', 'lightgreen']
plt.bar(categories, values, color=colors)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
# Bar Chart
categories = ['A', 'B', 'C']
values = [10, 20, 15]
plt.bar(categories, values, color='skyblue')
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
categories = ['A', 'B', 'C']
values = [10, 20, 15]
colors = ['skyblue', 'lightcoral', 'lightgreen']
plt.bar(categories, values, color=colors)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## Visualizations with Seaborn

# %% [markdown]
# ### Histogram and KDE plot

# %%
import seaborn as sns

# %%
data = np.random.randn(1000)
sns.histplot(data, kde=True, color='Green')
plt.title("Histogram with KDE")
plt.show()

# %% [markdown]
# ### Heatmap

# %%
matrix = np.random.rand(5, 5)
sns.heatmap(matrix, annot=True, cmap="prism")
plt.title("Heatmap Example")
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.set_style("whitegrid")
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species", markers=["o", "s", "D"])
plt.suptitle("Pair Plot Example", y=1.02)
plt.show()

# %% [markdown]
# ### Task

# %%
# read ice cream rating.csv
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pandas/Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
# set date as index
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
print(df)
# Out:
#             Flavor Rating  Texture Rating  Overall Rating
# Date
# 2022-01-01       0.223090        0.040220        0.600129
# 2022-01-02       0.635886        0.938476        0.106264
# 2022-01-03       0.442323        0.044154        0.598112
# 2022-01-04       0.389128        0.549676        0.489353
# 2022-01-05       0.386887        0.519439        0.988280
# 2022-01-06       0.877984        0.193588        0.832827
# 2022-01-07       0.140995        0.325110        0.105147

# %%
# scatter plot using texture rating and overall rating
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Texture Rating', y='Overall Rating', data=df, color='royalblue', alpha=0.8)
plt.title('Scatter Plot of Texture Rating vs. Overall Rating (Seaborn)')
plt.xlabel('Texture Rating')
plt.ylabel('Overall Rating')
plt.grid(True)
plt.show()

# %%
# hist plot
plt.figure(figsize=(8, 6))
sns.histplot(df['Overall Rating'], kde=True, color='lightgreen')
plt.title('Distribution of Overall Ratings (Seaborn)')
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# box plot
plt.figure(figsize=(6, 8))
sns.boxplot(y=df['Overall Rating'], color="lightcoral")
plt.title('Box Plot of Overall Ratings (Seaborn)')
plt.ylabel('Overall Rating')
plt.show()

# %%
# pie chart
